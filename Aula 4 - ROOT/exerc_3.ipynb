// %%
// gerando uma função gaussianda com os parâmetros desejados (média 5 e sigma 2), no intervalo de 0 a 10
TF1 f1("f1", "TMath::Gaus(x, 5, 2)", 0,10);
TCanvas canvas_1;


// Plotando
canvas_1.Draw();
f1.Draw();

// %%
// Criando o histograma
TH1F h1("Histograma", "Histograma do Exercicio 3", 50, 0, 10); // 50 bins entre 0 e 10

// Enchendo o histograma
for (int i=0;i<10000;i++) {h1.Fill(f1.GetRandom());}; //10 mil pontos gerados aleatóriamente com base em f1

//Plotando
gStyle->SetOptStat(101001111); // Definindo o que aparece na caixa de estatística

h1.Draw();
canvas_1.Draw();
// Out:
// Warning in <TROOT::Append>: Replacing existing TH1: Histograma (Potential memory leak).
