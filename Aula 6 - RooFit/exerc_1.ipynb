// %%
// Criando parâmetros da PDF crystall ball
RooRealVar x("x", "x", 0, -10, 10);
RooRealVar x0("x0", "x0", 1, -10, 10);
RooRealVar sigma("sigma", "sigma", 1, -10, 10);
RooRealVar alpha("alpha", "alpha", 1, -10, 10);
RooRealVar n("n", "n", 1, -10, 10);

// Criando a PDF
RooCBShape cb("cb", "Crystall Ball", x, x0, sigma, alpha, n);
// Out:
// RooFit v3.60 -- Developed by Wouter Verkerke and David Kirkby
//                 Copyright (C) 2000-2013 NIKHEF, University of California & Stanford University
//                 All rights reserved, please read http://roofit.sourceforge.net/license.txt

// %%
//Plotando a PDF
RooPlot* frame = x.frame();
cb.plotOn(frame);
frame->Draw();
c1->Draw();
// Out:
// Info in <TCanvas::MakeDefCanvas>:  created default TCanvas with name c1

// %%
// Gerando eventos com toy MC
RooDataSet* toyData = cb.generate(x, 10000);

// %%
// Plotando os dados com a pdf
RooPlot* frame = x.frame();
toyData->plotOn(frame);
cb.plotOn(frame);
frame->Draw();
c1->Draw();

// %%
// Fazendo o fit
cb.fitTo(*toyData);
// Out:
// [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
//  **********
//  **    1 **SET PRINT           1
//  **********
//  **********
//  **    2 **SET NOGRAD
//  **********
//  PARAMETER DEFINITIONS:
//     NO.   NAME         VALUE      STEP SIZE      LIMITS
//      1 alpha        1.00000e+00  2.00000e+00   -1.00000e+01  1.00000e+01
//      2 n            1.00000e+00  2.00000e+00   -1.00000e+01  1.00000e+01
//      3 sigma        1.00000e+00  2.00000e+00   -1.00000e+01  1.00000e+01
//      4 x0           1.00000e+00  2.00000e+00   -1.00000e+01  1.00000e+01
//  **********
//  **    3 **SET ERR         0.5
//  **********
//  **********
//  **    4 **SET PRINT           1
//  **********
//  **********
//  **    5 **SET STR           1
//  **********
//  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
//  **********
//  **    6 **MIGRAD        2000           1
//  **********
//  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
// ...

// %%
// Extra: fazendo o mesmo para a PDF exponencial

//Gerando Paramêtros
RooRealVar xExp("xExp", "xExp", 2, -10, 10);
RooRealVar cExp("cExp", "cExp", 2, -10, 10);

//Gerando a PDF
RooExponential exp("exp", "exponential", xExp, cExp);

//Gerando dados do toy MC
RooDataSet* toyDataExp = exp.generate(xExp, 10000);

//Plotando
RooPlot* frame = xExp.frame();
toyDataExp->plotOn(frame);
exp.plotOn(frame);
frame->Draw();
c1->Draw();
// Fazendo o fit
exp.fitTo(*toyDataExp);
// Out:
// [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
//  **********
//  **    1 **SET PRINT           1
//  **********
//  **********
//  **    2 **SET NOGRAD
//  **********
//  PARAMETER DEFINITIONS:
//     NO.   NAME         VALUE      STEP SIZE      LIMITS
//      1 cExp         2.00000e+00  2.00000e+00   -1.00000e+01  1.00000e+01
//  **********
//  **    3 **SET ERR         0.5
//  **********
//  **********
//  **    4 **SET PRINT           1
//  **********
//  **********
//  **    5 **SET STR           1
//  **********
//  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
//  **********
//  **    6 **MIGRAD         500           1
//  **********
//  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
//  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
//  FCN=3266.99 FROM MIGRAD    STATUS=INITIATE        4 CALLS           5 TOTAL
// ...

// %%
cExp.Print()
// Out:
// RooRealVar::cExp = 1.9611 +/- 0.019611  L(-10 - 10)
